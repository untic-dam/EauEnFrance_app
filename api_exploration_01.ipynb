# %% [markdown]
# # Import lib

# %%
import requests
import pandas as pd
import folium
import time
import random
import matplotlib.pyplot as plt
import datetime

# %%
#1 choisir une ville par numero de departement
#2 afficher la population de la ville comme un fun fact (avec une ampoule à coté)
#3 récupérer la liste des piezomètres avec l'opération 'station'
#4 afficher la position des n piézomètre
#5 Selectionner un piezomètre
#6 afficher les courbe de la chronique avec l'opération 'chronique'

# %% [markdown]
# # Recuperer le code Inses

# %%
def recup_commune(departement):
    #addresse api
    curl = f'https://geo.api.gouv.fr/communes?codePostal={str(departement)}'
    #requete api
    commune_req = requests.get(curl).json()
    
    #json
    commune = commune_req[0]
    
    #info
    insee = commune['code']
    ville = commune['nom']
    population = commune['population']
    
    return insee, ville, population

# %%
insee, ville, population = recup_commune(67000)

print("{} possède une population de {:,.0f} habitants".format(ville, population))
# Out:
# Strasbourg possède une population de 287,228 habitants

# %% [markdown]
# # Recuperer la liste des stations

# %%
def recup_list_stations(insee, ville):
    #code de la ville
    insee_str = str(insee)
    #url pour la requete
    station_url = f'https://hubeau.eaufrance.fr/api/v1/niveaux_nappes/stations?code_commune={insee_str}&format=json&size=20&pretty'
    station_req = requests.get(station_url).json()
    #list des stations piezometriques
    stations = station_req['data']

    print(f"il y a {len(stations)} station(s) à {ville}")
    
    return station_req, stations

# %%
station_req, stations = recup_list_stations(insee, ville)
# Out:
# il y a 20 station(s) à Strasbourg

# %% [markdown]
# # Choisir une stations

# %%
def print_station_date(station):
    #information pour être print
    n_mesures = station['nb_mesures_piezo']
    date_debut = station['date_debut_mesure']
    date_fin = station['date_fin_mesure']
    
    #recupère date sous format Timestamp
    date_debut = pd.to_datetime(date_debut)
    date_fin = pd.to_datetime(date_fin)
    
    #calcul deltat 
    delta_t = date_fin - date_debut
    delta_t_an = delta_t.days / 365
    delta_t_mois = delta_t.days / 30
    
    #mise en forme
    delta_t_str = "{:.2f}".format(delta_t_an)
    moy = n_mesures/(delta_t_mois) #permet d'avoir une idée de la résolution temporelle du graphique
    moy_str = "{:.2f} mesures/mois".format(moy)
    
    #mise en forme des dates debut et fin
    date_debut_str = date_debut.strftime("%Y-%m-%d")
    date_fin_str = date_fin.strftime("%Y-%m-%d")
    
    print(f"il y a {n_mesures} mesures | {date_debut_str} -> {date_fin_str} ({delta_t_str} ans) | moyenne = {moy_str}")



def random_station(stations):
    n_stations = len(stations) - 1
    idx = random.randint(0,n_stations)

    station = stations[idx]
    
    print_station_date(station)
    
    return station

station = random_station(stations)
# Out:
# il y a 210 mesures | 1969-09-18 -> 1985-12-16 (16.25 ans) | moyenne = 1.06 mesures/mois

# %%
df_stations = pd.DataFrame(stations)

# %%
df_stations
# Out:
#             code_bss                                            urn_bss  \
# 0   02723X0255/SOC10  http://services.ades.eaufrance.fr/pointeau/027...
# 1     02723X0110/S20  http://services.ades.eaufrance.fr/pointeau/027...
# 2   02723X0361/SOC30  http://services.ades.eaufrance.fr/pointeau/027...
# 3     02723X0293/S40  http://services.ades.eaufrance.fr/pointeau/027...
# 4     02727X0037/S50  http://services.ades.eaufrance.fr/pointeau/027...
# 5     02347X0001/501  http://services.ades.eaufrance.fr/pointeau/023...
# 6   02723X0189/SOC11  http://services.ades.eaufrance.fr/pointeau/027...
# 7   02723X0279/SOC21  http://services.ades.eaufrance.fr/pointeau/027...
# 8     02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
# 9     02723X0294/S41  http://services.ades.eaufrance.fr/pointeau/027...
# 10  02723X0878/GET41  http://services.ades.eaufrance.fr/pointeau/027...
# 11  02723X1186/AMT_1  http://services.ades.eaufrance.fr/pointeau/027...
# 12  02723X0098/245A1  http://services.ades.eaufrance.fr/pointeau/027...
# 13    02347X0060/GA1  http://services.ades.eaufrance.fr/pointeau/023...
# 14   02723X0238/SOC1  http://services.ades.eaufrance.fr/pointeau/027...
# 15     02723X0968/F1  http://services.ades.eaufrance.fr/pointeau/027...
# 16     02723X0631/P1  http://services.ades.eaufrance.fr/pointeau/027...
# 17     02347X0083/P1  http://services.ades.eaufrance.fr/pointeau/023...
# 18     02723X1200/R1  http://services.ades.eaufrance.fr/pointeau/027...
# 19  02723X0900/245R1  http://services.ades.eaufrance.fr/pointeau/027...
#
#    date_debut_mesure date_fin_mesure code_commune_insee nom_commune         x  \
# 0         1969-05-10      1985-12-16              67482  Strasbourg  7.783675
# 1         1971-01-12      1971-08-31              67482  Strasbourg  7.779212
# 2         1969-10-21      1997-01-29              67482  Strasbourg  7.784080
# 3         1971-01-12      1972-07-25              67482  Strasbourg  7.798671
# 4         1971-01-12      1972-07-25              67482  Strasbourg  7.789253
# 5         1967-07-19      1998-01-28              67482  Strasbourg  7.804221
# 6         1969-05-08      1985-12-16              67482  Strasbourg  7.760567
# 7         1969-09-18      1985-12-16              67482  Strasbourg  7.741601
# 8         1971-01-12      1972-07-25              67482  Strasbourg  7.787881
# 9         1971-01-26      1972-07-25              67482  Strasbourg  7.792740
# 10        1988-10-21      1996-06-27              67482  Strasbourg  7.752935
# 11        1998-12-08      1998-12-08              67482  Strasbourg  7.737233
# 12        1966-07-01      1999-12-16              67482  Strasbourg  7.766629
# 13        1968-11-12      1997-01-13              67482  Strasbourg  7.809233
# 14        1969-06-07      1990-01-18              67482  Strasbourg  7.748228
# 15        1990-08-28      1990-08-29              67482  Strasbourg  7.765793
# 16        1983-03-23      1983-08-18              67482  Strasbourg  7.797790
# 17        1973-01-24      1977-12-29              67482  Strasbourg  7.759789
# 18        1999-09-17      2000-03-24              67482  Strasbourg  7.784897
# 19        1988-06-16      2021-12-14              67482  Strasbourg  7.748164
#
#             y codes_bdlisa                                        urns_bdlisa  \
# 0   48.594645    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 1   48.528374    [221AA17]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 2   48.541528    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 3   48.530051    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 4   48.509678    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 5   48.632254    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 6   48.565818    [221AA17]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 7   48.587244    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 8   48.526965    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 9   48.519248    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 10  48.577733    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 11  48.563588    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 12  48.511892    [221AA17]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 13  48.602935    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 14  48.582438    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 15  48.536050    [221AA17]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 16  48.598670    [221AA17]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 17  48.600801    [221AA17]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 18  48.543914    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
# 19  48.583983    [221AA19]  [http://reseau.eaufrance.fr/geotraitements/bdl...
#
#     ... altitude_station nb_mesures_piezo code_departement  nom_departement  \
# 0   ...            136.8              250               67         Bas-Rhin
# 1   ...            140.4               30               67         Bas-Rhin
# 2   ...            140.7              196               67         Bas-Rhin
# 3   ...            140.4               68               67         Bas-Rhin
# 4   ...            141.9               69               67         Bas-Rhin
# 5   ...           134.65              107               67         Bas-Rhin
# 6   ...            138.7              247               67         Bas-Rhin
# 7   ...            138.7              210               67         Bas-Rhin
# 8   ...            140.6               69               67         Bas-Rhin
# 9   ...            139.7               65               67         Bas-Rhin
# 10  ...           140.23              117               67         Bas-Rhin
# 11  ...            139.0                1               67         Bas-Rhin
# 12  ...           142.95             1327               67         Bas-Rhin
# 13  ...           135.34              596               67         Bas-Rhin
# 14  ...           143.76              384               67         Bas-Rhin
# 15  ...           139.48                2               67         Bas-Rhin
# 16  ...           137.21                3               67         Bas-Rhin
# 17  ...            137.0               70               67         Bas-Rhin
# 18  ...            142.0                3               67         Bas-Rhin
# 19  ...           141.51             1672               67         Bas-Rhin
#
#                                        libelle_pe profondeur_investigation  \
# 0                                            None                      NaN
# 1                                            None                      9.8
# 2                                            None                      NaN
# 3                                            None                     10.0
# 4                                            None                      7.1
# 5   Puits de MAISON FORESTIERE DE FUCHS AM BUCKEL                      4.8
# 6                                            None                      5.4
# 7                                            None                      8.0
# 8                                            None                     12.0
# 9                                            None                     10.0
# 10                                           None                     36.5
# 11                                           None                      8.0
# 12               Forage de OBERJAEGERHOF (NEUHOF)                      8.2
# 13                                           None                      NaN
# 14                                           None                     11.5
# 15                                           None                      4.5
# 16                                           None                      4.1
# 17                                           None                      NaN
# 18                                           None                      NaN
# 19                   Puits de PLACE DES ETUDIANTS                     10.4
#
#    codes_masse_eau_edl                                 noms_masse_eau_edl  \
# 0              [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 1              [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 2              [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 3              [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 4              [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 5              [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 6              [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 7              [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 8              [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 9              [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 10             [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 11             [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 12             [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 13             [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 14             [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 15             [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 16             [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 17             [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 18             [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
# 19             [CG101]  [Nappe d’Alsace, Pliocène de Haguenau et Oligo...
#
#                                    urns_masse_eau_edl  \
# 0   [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 1   [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 2   [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 3   [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 4   [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 5   [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 6   [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 7   [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 8   [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 9   [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 10  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 11  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 12  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 13  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 14  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 15  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 16  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 17  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 18  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
# 19  [http://www.sandre.eaufrance.fr/geo/MasseDEauS...
#
#                          date_maj
# 0   Wed Apr 22 20:39:08 CEST 2020
# 1   Wed Apr 22 20:39:08 CEST 2020
# 2   Thu Apr 23 07:32:19 CEST 2020
# 3   Thu Apr 23 07:32:19 CEST 2020
# 4   Wed Apr 22 20:39:08 CEST 2020
# 5   Wed Apr 22 08:04:52 CEST 2020
# 6   Wed Apr 22 20:39:08 CEST 2020
# 7   Thu Apr 23 07:32:19 CEST 2020
# 8   Wed Apr 22 20:39:08 CEST 2020
# 9   Thu Apr 23 07:32:19 CEST 2020
# 10  Wed Apr 22 20:39:08 CEST 2020
# 11  Tue Apr 21 20:20:26 CEST 2020
# 12   Tue Jan 28 19:02:11 CET 2020
# 13  Wed Apr 22 08:06:25 CEST 2020
# 14  Wed Apr 22 20:39:08 CEST 2020
# 15  Tue Apr 21 20:20:08 CEST 2020
# 16  Wed Apr 22 20:39:08 CEST 2020
# 17  Wed Apr 22 20:39:08 CEST 2020
# 18  Tue Apr 21 20:20:26 CEST 2020
# 19   Tue Jan 28 19:02:12 CET 2020
#
# [20 rows x 22 columns]

# %% [markdown]
# # Recup la chronique de la station

# %%
def recup_chronique(station, size=1000):
    code_bss = str(station['code_bss'])
    
    chronique_url = f'https://hubeau.eaufrance.fr/api/v1/niveaux_nappes/chroniques?code_bss={code_bss}&size={str(size)}'

    chronique_req = requests.get(chronique_url).json()
    chroniques = chronique_req['data']
    print(f"il y a {len(chroniques)} mesure(s)")
    
    return chronique_req, chroniques

chronique_req, chroniques = recup_chronique(station)
# Out:
# il y a 210 mesure(s)

# %%
chronique_req.keys()
# Out:
# dict_keys(['count', 'first', 'last', 'prev', 'next', 'api_version', 'data'])

# %%
chroniques[0]
# Out:
# {'code_bss': '02723X0279/SOC21',
#  'urn_bss': 'http://services.ades.eaufrance.fr/pointeau/02723X0279/SOC21',
#  'date_mesure': '1969-09-18',
#  'timestamp_mesure': -9072000000,
#  'niveau_nappe_eau': 135.51,
#  'mode_obtention': "Mode d'obtention inconnu",
#  'statut': 'Donnée brute',
#  'qualification': 'Non qualifié',
#  'code_continuite': '2',
#  'nom_continuite': 'Point lié au point précédent',
#  'code_producteur': '299',
#  'nom_producteur': 'Service Géologique Régional Alsace (299)',
#  'code_nature_mesure': None,
#  'nom_nature_mesure': None,
#  'profondeur_nappe': 3.4}

# %%
df_chronique = pd.DataFrame(chroniques)
df_chronique
# Out:
#           code_bss                                            urn_bss  \
# 0   02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
# 1   02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
# 2   02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
# 3   02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
# 4   02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
# ..             ...                                                ...
# 64  02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
# 65  02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
# 66  02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
# 67  02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
# 68  02723X0121/S21  http://services.ades.eaufrance.fr/pointeau/027...
#
#    date_mesure  timestamp_mesure  niveau_nappe_eau            mode_obtention  \
# 0   1971-01-12       32486400000            136.23  Mode d'obtention inconnu
# 1   1971-01-19       33091200000            136.02  Mode d'obtention inconnu
# 2   1971-01-26       33696000000            136.62  Mode d'obtention inconnu
# 3   1971-02-02       34300800000            136.34  Mode d'obtention inconnu
# 4   1971-02-09       34905600000            136.24  Mode d'obtention inconnu
# ..         ...               ...               ...                       ...
# 64  1972-06-27       78451200000            136.26  Mode d'obtention inconnu
# 65  1972-07-04       79056000000            136.41  Mode d'obtention inconnu
# 66  1972-07-11       79660800000            136.35  Mode d'obtention inconnu
# 67  1972-07-18       80265600000            136.37  Mode d'obtention inconnu
# 68  1972-07-25       80870400000            136.71  Mode d'obtention inconnu
#
#           statut qualification code_continuite                nom_continuite  \
# 0   Donnée brute  Non qualifié               2  Point lié au point précédent
# 1   Donnée brute  Non qualifié               2  Point lié au point précédent
# 2   Donnée brute  Non qualifié               2  Point lié au point précédent
# 3   Donnée brute  Non qualifié               2  Point lié au point précédent
# 4   Donnée brute  Non qualifié               2  Point lié au point précédent
# ..           ...           ...             ...                           ...
# 64  Donnée brute  Non qualifié               2  Point lié au point précédent
# 65  Donnée brute  Non qualifié               2  Point lié au point précédent
# 66  Donnée brute  Non qualifié               2  Point lié au point précédent
# 67  Donnée brute  Non qualifié               2  Point lié au point précédent
# 68  Donnée brute  Non qualifié               2  Point lié au point précédent
#
#    code_producteur                            nom_producteur  \
# 0              299  Service Géologique Régional Alsace (299)
# 1              299  Service Géologique Régional Alsace (299)
# 2              299  Service Géologique Régional Alsace (299)
# 3              299  Service Géologique Régional Alsace (299)
# 4              299  Service Géologique Régional Alsace (299)
# ..             ...                                       ...
# 64             299  Service Géologique Régional Alsace (299)
# 65             299  Service Géologique Régional Alsace (299)
# 66             299  Service Géologique Régional Alsace (299)
# 67             299  Service Géologique Régional Alsace (299)
# 68             299  Service Géologique Régional Alsace (299)
#
#    code_nature_mesure nom_nature_mesure  profondeur_nappe
# 0                None              None              6.28
# 1                None              None              6.49
# 2                None              None              5.89
# 3                None              None              6.17
# 4                None              None              6.27
# ..                ...               ...               ...
# 64               None              None              6.25
# 65               None              None              6.10
# 66               None              None              6.16
# 67               None              None              6.14
# 68               None              None              5.80
#
# [69 rows x 15 columns]

# %%
df_chronique.to_csv('data.csv', index=False)
df = pd.read_csv('data.csv', index_col='date_mesure', parse_dates=True)

# %%
df_chronique['date_mesure'] = pd.to_datetime(df_chronique['date_mesure'])

# %%
df['niveau_nappe_eau'].plot()
# Out:
# <AxesSubplot:xlabel='date_mesure'>

# %%
df['niveau_nappe_eau'].resample('Y').mean().plot()
# Out:
# <AxesSubplot:xlabel='date_mesure'>

# %%
#m = bitcoin['Close'].resample('W').agg(['mean', 'std', 'min', 'max'])
m = df['niveau_nappe_eau'].resample('Y').agg(['mean', 'std', 'min', 'max'])

plt.figure(figsize=(12, 8))
m['mean'].plot(label='moyenne par semaine')
plt.fill_between(m.index, m['max'], m['min'], alpha=0.2, label='min-max par semaine')

plt.legend()
plt.show()
